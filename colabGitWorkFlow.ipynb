# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/CAPSTONE/Husein/Recomendation_Learn/Upload to Git

# %%
# !ls -a

# %%
# !pwd

# %%
# !git init

# %%
# !ls -a

# %%
# !git remote add origin https://huseinabdulh:huuseeiinn18@github.com/huseinabdulh/RecomendationSystemLearn.git
# !git remote -v

# %%
# !git config --global user.email 'huseinabdulh@gmail.com'
# !git config --global user.name 'huseinabdulh'

# %%
# !git add .
# !git commit -m 'First commit'

# %%
# !git push origin master
